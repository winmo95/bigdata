# %%
import pandas as pd
import numpy as np

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
busan = pd.read_csv('../data/busan1.csv')

# %%
busan
# Out:
#     회계연도 지역명   자치단체코드 자치단체명                회계구분명            총지출액
# 0   2016  부산  2600000  부산본청                 일반회계  97233425608853
# 1   2016  부산  2600000  부산본청             경륜사업특별회계    330265000000
# 2   2016  부산  2600000  부산본청        공영차고지조성사업특별회계     10136959480
# 3   2016  부산  2600000  부산본청           광역교통시설특별회계    519964939930
# 4   2016  부산  2600000  부산본청             교통사업특별회계   1332569179880
# 5   2016  부산  2600000  부산본청         기반시설부담구역특별회계               0
# 6   2016  부산  2600000  부산본청             남북교류협력기금     10000000000
# 7   2016  부산  2600000  부산본청          대학및지역인재육성기금     21793156660
# 8   2016  부산  2600000  부산본청          도시및주거환경정비기금    288195191940
# 9   2016  부산  2600000  부산본청           도시철도사업특별회계   6146631541940
# 10  2016  부산  2600000  부산본청               문화진흥기금      5111723370
# 11  2016  부산  2600000  부산본청               사회복지기금      3194542900
# 12  2016  부산  2600000  부산본청             소방사업특별회계   8700915405583
# ...

# %%
import platform
from matplotlib import font_manager, rc

path = "c:/Windows/Fonts/malgun.ttf"
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system.')

# %%
sns.barplot(x='회계구분명',y='총지출액', data=busan)

# %%
busan.sort_values(by='총지출액',ascending = False)
# Out:
#     회계연도 지역명   자치단체코드 자치단체명                회계구분명            총지출액
# 0   2016  부산  2600000  부산본청                 일반회계  97233425608853
# 16  2016  부산  2600000  부산본청           의료급여기금특별회계   9249812467070
# 12  2016  부산  2600000  부산본청             소방사업특별회계   8700915405583
# 9   2016  부산  2600000  부산본청           도시철도사업특별회계   6146631541940
# 22  2016  부산  2600000  부산본청              지방채상환기금   3061331595380
# 30  2016  부산  2600000  부산본청       항만배후도로건설사업특별회계   2380704511990
# 4   2016  부산  2600000  부산본청             교통사업특별회계   1332569179880
# 27  2016  부산  2600000  부산본청               통합관리기금   1038414893370
# 3   2016  부산  2600000  부산본청           광역교통시설특별회계    519964939930
# 21  2016  부산  2600000  부산본청             중소기업육성기금    453764507510
# 18  2016  부산  2600000  부산본청               재난관리기금    430263549340
# 1   2016  부산  2600000  부산본청             경륜사업특별회계    330265000000
# 14  2016  부산  2600000  부산본청        원자력발전지역개발특별회계    312429418620
# ...

# %%
incheon = pd.read_csv('../data/incheon.csv')

# %%
incheon.head()
# Out:
#   지역명   자치단체코드 자치단체명              회계구분명            지출합계
# 0  인천  2800000  인천본청  검단1지구토지구획정리사업특별회계     11217778695
# 1  인천  2800000  인천본청  검단2지구토지구획정리사업특별회계  89636912192189
# 2  인천  2800000  인천본청     검단폐수종말처리시설특별회계       144000000
# 3  인천  2800000  인천본청         광역교통시설특별회계  80827651075001
# 4  인천  2800000  인천본청           기반시설특별회계  10903194928659

# %%
incheon.sort_values(by='지출합계', ascending = False)
# Out:
#    지역명   자치단체코드 자치단체명                    회계구분명            지출합계
# 25  인천  2800000  인천본청                     일반회계  89636912192189
# 1   인천  2800000  인천본청        검단2지구토지구획정리사업특별회계  89636912192189
# 15  인천  2800000  인천본청                   소방특별회계  89427255681949
# 9   인천  2800000  인천본청               도시교통사업특별회계  89304538093661
# 17  인천  2800000  인천본청                   식품진흥기금  82527557569767
# 14  인천  2800000  인천본청                   사회복지기금  82177928689829
# 19  인천  2800000  인천본청                  에너지사업기금  81994977195610
# 3   인천  2800000  인천본청               광역교통시설특별회계  80827651075001
# 16  인천  2800000  인천본청                 수질개선특별회계  77141827839354
# 11  인천  2800000  인천본청               도시철도사업특별회계  74898125849978
# 27  인천  2800000  인천본청                 재난안전특별회계  72498989376289
# 20  인천  2800000  인천본청         오류지구토지구획정리사업특별회계  66267285671074
# 31  인천  2800000  인천본청                  지방채상환기금  65924763434746
# 24  인천  2800000  인천본청         인천광역시아시아경기대회특별회계  65778460000526
# ...

# %%
inch = incheon.sort_values(by='지출합계', ascending = False).head(n=10)

# %%
inch
# Out:
#    지역명   자치단체코드 자치단체명              회계구분명            지출합계
# 25  인천  2800000  인천본청               일반회계  89636912192189
# 1   인천  2800000  인천본청  검단2지구토지구획정리사업특별회계  89636912192189
# 15  인천  2800000  인천본청             소방특별회계  89427255681949
# 9   인천  2800000  인천본청         도시교통사업특별회계  89304538093661
# 17  인천  2800000  인천본청             식품진흥기금  82527557569767
# 14  인천  2800000  인천본청             사회복지기금  82177928689829
# 19  인천  2800000  인천본청            에너지사업기금  81994977195610
# 3   인천  2800000  인천본청         광역교통시설특별회계  80827651075001
# 16  인천  2800000  인천본청           수질개선특별회계  77141827839354
# 11  인천  2800000  인천본청         도시철도사업특별회계  74898125849978

# %%
sns.barplot(x='회계구분명',y='지출합계', data=inch)

# %%
del busan['지역명']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '지역명'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-47-f7c8ce811507> in <module>()
# ----> 1 del busan['지역명']
#
# ...

# %%
del busan['회계연도']
del busan['자치단체명']

# %%
inch['지출합계'].plot(kind = 'bar' ,grid =True, figsize=(10,10))

# %%
del busan['자치단체코드']

# %%
busan['총지출액'].plot(kind = 'bar' ,grid =True, figsize=(10,10))
plt.plot
# Out:
# <function matplotlib.pyplot.plot(*args, **kwargs)>

# %%
busan.set_index('회계구분명',inplace=True)

# %%
busan['총지출액'].plot(kind = 'bar' ,grid =True, figsize=(10,10))

# %%
busan1 = busan.sort_values(by='총지출액', ascending = False).head(n=10)

# %%
busan1['총지출액'].plot(kind = 'bar' ,grid =True, figsize=(10,10))
