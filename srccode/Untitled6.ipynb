# %%
from bs4 import BeautifulSoup
import pandas as pd

# %%
from urllib.request import urlopen

url_base = "https://www.premierleague.com/stats/top/clubs/goals?se=210"

page = urlopen(url_base)

soup = BeautifulSoup(page,'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta content="Premier League Club Stats - Goals" name="twitter:title"/>
# <meta content="Premier League, Football, Soccer, Official" name="keywords"/>
# <meta content="website" property="og:type"/>
# <meta content="View Goals played by Premier League clubs for 2018/19 and previous seasons, on the official website of the Premier League." name="description"/>
# <meta content="View Goals played by Premier League clubs for 2018/19 and previous seasons, on the official website of the Premier League." name="twitter:description"/>
# <meta content="https://s3.amazonaws.com/premierleague-static-files/premierleague/pl_icon.png" name="twitter:image"/>
# <meta content="Premier League Club Stats - Goals" property="og:title"/>
# <meta content="https://s3.amazonaws.com/premierleague-static-files/premierleague/pl_icon.png" property="og:image"/>
# <title>Premier League Club Stats - Goals</title>
# <meta content="#38003C" name="theme-color"/>
# ...

# %%
soup.find_all("td","mainStat")
# Out:
# []

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-71db9aecf075> in <module>
# ----> 1 k.find_all("td")
#
# D:\Anaconda3\lib\site-packages\bs4\element.py in __getattr__(self, key)
#    1882     def __getattr__(self, key):
#    1883         raise AttributeError(
# -> 1884             "ResultSet object has no attribute '%s'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?" % key
#    1885         )
#
# AttributeError: ResultSet object has no attribute 'find_all'. You're probably treating a list of items like a single item. Did you call find_all() when you meant to call find()?
