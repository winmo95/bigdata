# %%
from bs4 import BeautifulSoup
import pandas as pd

# %%
from urllib.request import urlopen

url_base = "http://movie.naver.com/"
url_syb = "movie/sdb/rank/rmovie.nhn?sel=cur&date=20180719"

page = urlopen(url_base+url_syb)

soup = BeautifulSoup(page,'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html>
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="me2:image">
# <meta content="네이버영화 " property="me2:post_tag">
# <meta content="네이버영화" property="me2:category1"/>
# <meta content="" property="me2:category2"/>
# <meta content="랭킹 : 네이버 영화" property="og:title"/>
# <meta content="영화, 영화인, 예매, 박스오피스 랭킹 정보 제공" property="og:description"/>
# <meta content="article" property="og:type"/>
# <meta content="https://movie.naver.com/movie/sdb/rank/rmovie.nhn?sel=cur&amp;date=20180719" property="og:url"/>
# <meta content="http://static.naver.net/m/movie/icons/OG_270_270.png" property="og:image"/><!-- http://static.naver.net/m/movie/im/navermovie.jpg -->
# <meta content="http://imgmovie.naver.com/today/naverme/naverme_profile.jpg" property="og:article:thumbnailUrl"/>
# ...

# %%
soup.find_all('div','tit5')
# Out:
# [<div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=157243" title="당갈">당갈</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=169240" title="아일라">아일라</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=167787" title="허스토리">허스토리</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=154667" title="덕구">덕구</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=17170" title="레옹">레옹</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=10058" title="벤허">벤허</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=10173" title="사랑과 영혼">사랑과 영혼</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=136990" title="인크레더블 2">인크레더블 2</a>
#  </div>, <div class="tit5">
#  <a href="/movie/bi/mi/basic.nhn?code=136315" title="어벤져스: 인피니티 워">어벤져스: 인피니티 워</a>
#  </div>, <div class="tit5">
# ...

# %%
soup.find_all('div','tit5')[0]
# Out:
# <div class="tit5">
# <a href="/movie/bi/mi/basic.nhn?code=157243" title="당갈">당갈</a>
# </div>

# %%
soup.find_all('div','tit5')[0].a  #<a> 로시작해서 </a>fh 끝나는 문장을 가져오자
# Out:
# <a href="/movie/bi/mi/basic.nhn?code=157243" title="당갈">당갈</a>

# %%
soup.find_all('div','tit5')[0].a.string
# Out:
# '당갈'

# %%
soup.find_all('td','point')  # 평점 가져오기
# Out:
# [<td class="point">9.56</td>,
#  <td class="point">9.55</td>,
#  <td class="point">9.48</td>,
#  <td class="point">9.48</td>,
#  <td class="point">9.37</td>,
#  <td class="point">9.22</td>,
#  <td class="point">9.17</td>,
#  <td class="point">9.16</td>,
#  <td class="point">8.97</td>,
#  <td class="point">8.90</td>,
#  <td class="point">8.88</td>,
#  <td class="point">8.88</td>,
#  <td class="point">8.86</td>,
#  <td class="point">8.83</td>,
#  <td class="point">8.83</td>,
#  <td class="point">8.74</td>,
#  <td class="point">8.74</td>,
#  <td class="point">8.73</td>,
#  <td class="point">8.73</td>,
#  <td class="point">8.71</td>,
#  <td class="point">8.69</td>,
#  <td class="point">8.68</td>,
#  <td class="point">8.65</td>,
#  <td class="point">8.60</td>,
#  <td class="point">8.58</td>,
#  <td class="point">8.54</td>,
#  <td class="point">8.51</td>,
#  <td class="point">8.30</td>,
#  <td class="point">8.26</td>,
#  <td class="point">8.22</td>,
#  <td class="point">8.21</td>,
# ...

# %%
soup.find_all('td','point')[0]
# Out:
# <td class="point">9.56</td>

# %%
len(soup.find_all('td','point'))
# Out:
# 46

# %%
soup.find_all('td','point')[0].string
# Out:
# '9.56'

# %%
movie_name = [soup.find_all('div','tit5')[n].a.string for n in range(0,46)]
movie_name
# Out:
# ['당갈',
#  '아일라',
#  '허스토리',
#  '덕구',
#  '레옹',
#  '벤허',
#  '사랑과 영혼',
#  '인크레더블 2',
#  '어벤져스: 인피니티 워',
#  '미드나잇 선',
#  '마당을 나온 암탉',
#  '소공녀',
#  '아이 필 프리티',
#  '아무도 모른다',
#  '그렇게 아버지가 된다',
#  '바닷마을 다이어리',
#  '리틀 포레스트',
#  '부르고뉴, 와인에서 찾은 인생',
#  '더 포스트',
#  '개들의 섬',
#  '앤트맨과 와스프',
#  '블레이드 2',
#  '걸어도 걸어도',
#  '태풍이 지나가고',
#  '탐정: 리턴즈',
#  '시카리오: 데이 오브 솔다도',
#  '오늘 밤, 로맨스 극장에서',
#  '여고괴담 두번째 이야기',
#  '시카리오: 암살자의 도시',
#  '스카이스크래퍼',
#  '판의 미로 - 오필리아와 세 개의 열쇠',
#  '마녀',
#  '쥬라기 월드: 폴른 킹덤',
#  '제로 다크 서티',
#  '나의 산티아고',
#  '변산',
#  '파리로 가는 길',
#  '오션스8',
#  '세 번째 살인',
#  '독전',
#  '유전',
#  '안녕, 나의 소녀',
#  '버닝',
#  '나라타주',
#  '경성학교: 사라진 소녀들',
#  '속닥속닥']

# %%
movie_point = [soup.find_all('td','point')[n].string for n in range(0,46)]
movie_point
# Out:
# ['9.56',
#  '9.55',
#  '9.48',
#  '9.48',
#  '9.37',
#  '9.22',
#  '9.17',
#  '9.16',
#  '8.97',
#  '8.90',
#  '8.88',
#  '8.88',
#  '8.86',
#  '8.83',
#  '8.83',
#  '8.74',
#  '8.74',
#  '8.73',
#  '8.73',
#  '8.71',
#  '8.69',
#  '8.68',
#  '8.65',
#  '8.60',
#  '8.58',
#  '8.54',
#  '8.51',
#  '8.30',
#  '8.26',
#  '8.22',
#  '8.21',
#  '8.20',
#  '8.17',
#  '8.16',
#  '8.13',
#  '7.97',
#  '7.91',
#  '7.86',
#  '7.79',
#  '7.66',
#  '7.28',
#  '6.69',
#  '6.65',
#  '6.48',
#  '6.12',
#  '5.80']

# %%
date = pd.date_range('2018-1-1', periods=200, freq='D') #2018-1-1 에서 시작하여 기간 200일동안의 데이터
date
# Out:
# DatetimeIndex(['2018-01-01', '2018-01-02', '2018-01-03', '2018-01-04',
#                '2018-01-05', '2018-01-06', '2018-01-07', '2018-01-08',
#                '2018-01-09', '2018-01-10',
#                ...
#                '2018-07-10', '2018-07-11', '2018-07-12', '2018-07-13',
#                '2018-07-14', '2018-07-15', '2018-07-16', '2018-07-17',
#                '2018-07-18', '2018-07-19'],
#               dtype='datetime64[ns]', length=200, freq='D')

# %%
import urllib
from tqdm import tqdm_notebook
movie_date = []
movie_name = []
movie_point = []

for today in tqdm_notebook(date):
    html = "http://movie.naver.com/" + \
                                    "movie/sdb/rank/rmovie.nhn?sel=cur&date={date}"
    response = urlopen(html.format(date=
                                   urllib.parse.quote(today.strftime('%Y%m%d'))))
    soup = BeautifulSoup(response, "html.parser")
    
    end = len(soup.find_all('td', 'point'))
    
    movie_date.extend([today for n in range(0, end)])
    movie_name.extend([soup.find_all('div', 'tit5')[n].a.string for n in range(0, end)])
    movie_point.extend([soup.find_all('td', 'point')[n].string for n in range(0, end)])

# %%
len(movie_date),len(movie_name),len(movie_point)
# Out:
# (8411, 8411, 8411)

# %%
today
# Out:
# Timestamp('2018-07-19 00:00:00', freq='D')

# %%
movie = pd.DataFrame({'date':movie_date, 'name': movie_name, 'point': movie_point})
movie.head()
# Out:
#         date        name point
# 0 2018-01-01          원더  9.45
# 1 2018-01-01      위대한 쇼맨  9.44
# 2 2018-01-01  다시 태어나도 우리  9.33
# 3 2018-01-01        1987  9.25
# 4 2018-01-01      러빙 빈센트  9.19

# %%
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8411 entries, 0 to 8410
# Data columns (total 3 columns):
# date     8411 non-null datetime64[ns]
# name     8411 non-null object
# point    8411 non-null object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 197.2+ KB

# %%
movie['point'] = movie['point'].astype(float) #타입변경
movie.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8411 entries, 0 to 8410
# Data columns (total 3 columns):
# date     8411 non-null datetime64[ns]
# name     8411 non-null object
# point    8411 non-null float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 197.2+ KB

# %%
import numpy as np

movie_unqiue = pd.pivot_table(movie, index=['name'], aggfunc=np.sum)
movie_best =movie_unqiue.sort_values(by='point',ascending=False)
movie_best.head()
# Out:
#                 point
# name
# 위대한 쇼맨        1689.08
# 러빙 빈센트        1452.24
# 원더            1194.13
# 안녕, 나의 소울메이트  1060.34
# 소공녀           1035.87

# %% [markdown]
# tmp = movie.query('name == ["어벤져스: 인피니티 워"]')
# tmp

# %%
tmp = movie.query('name == ["어벤져스: 인피니티 워"]')
tmp.head()
# Out:
#            date          name  point
# 4854 2018-04-25  어벤져스: 인피니티 워   9.17
# 4901 2018-04-26  어벤져스: 인피니티 워   9.18
# 4951 2018-04-27  어벤져스: 인피니티 워   9.16
# 5001 2018-04-28  어벤져스: 인피니티 워   9.11
# 5053 2018-04-29  어벤져스: 인피니티 워   9.07

# %%
tmp2 = movie.query('name == ["코코"]') #영화 명 바꿔서 해보기
tmp2.head()
# Out:
#           date name  point
# 346 2018-01-11   코코   9.30
# 382 2018-01-12   코코   9.24
# 418 2018-01-13   코코   9.20
# 459 2018-01-14   코코   9.16
# 495 2018-01-15   코코   9.15

# %%
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt2
# %matplotlib inline

plt.figure(figsize=(12,8))
plt.plot(tmp['date'], tmp['point'])
plt.legend(loc='best')
plt.grid()
plt.show()

plt2.figure(figsize=(12,8))
plt2.plot(tmp2['date'], tmp2['point'])
plt2.legend(tmp2.name, loc='best')
plt2.grid()
plt2.show()

# %%
movie_pivot= pd.pivot_table(movie, index=['date'], columns=['name'], values=['point'])
movie_pivot.head()
# NaN => 데이터 없음 개봉을 안한는등 여러가지 이유로
# Out:
#             point                                                  \
# name       12 솔져스 120BPM  1987 1급기밀  4등 50가지 그림자: 해방 7년의 밤 B급 며느리
# date
# 2018-01-01    NaN    NaN  9.25  NaN NaN          NaN   NaN    NaN
# 2018-01-02    NaN    NaN  9.26  NaN NaN          NaN   NaN    NaN
# 2018-01-03    NaN    NaN  9.25  NaN NaN          NaN   NaN    NaN
# 2018-01-04    NaN    NaN  9.25  NaN NaN          NaN   NaN    NaN
# 2018-01-05    NaN    NaN  9.26  NaN NaN          NaN   NaN    NaN
#
#                                ...                                     \
# name       가장 따뜻한 색, 블루   강철비  ...  하이 스피드! –프리! 스타팅 데이즈 하이큐!! 재능과 센스
# date                           ...
# 2018-01-01         8.82  8.48  ...                   NaN          NaN
# 2018-01-02         8.82  8.49  ...                   NaN          NaN
# 2018-01-03         8.82  8.49  ...                   NaN          NaN
# 2018-01-04         8.82  8.49  ...                   NaN          NaN
# ...

# %%
movie_pivot.columns = movie_pivot.columns.droplevel()

# %%
movie_pivot.head()
# Out:
# name        12 솔져스  120BPM  1987  1급기밀  4등  50가지 그림자: 해방  7년의 밤  B급 며느리  \
# date
# 2018-01-01     NaN     NaN  9.25   NaN NaN           NaN    NaN     NaN
# 2018-01-02     NaN     NaN  9.26   NaN NaN           NaN    NaN     NaN
# 2018-01-03     NaN     NaN  9.25   NaN NaN           NaN    NaN     NaN
# 2018-01-04     NaN     NaN  9.25   NaN NaN           NaN    NaN     NaN
# 2018-01-05     NaN     NaN  9.26   NaN NaN           NaN    NaN     NaN
#
# name        가장 따뜻한 색, 블루   강철비  ...   하이 스피드! –프리! 스타팅 데이즈  하이큐!! 재능과 센스  \
# date                            ...
# 2018-01-01          8.82  8.48  ...                    NaN           NaN
# 2018-01-02          8.82  8.49  ...                    NaN           NaN
# 2018-01-03          8.82  8.49  ...                    NaN           NaN
# 2018-01-04          8.82  8.49  ...                    NaN           NaN
# 2018-01-05          8.82  8.49  ...                    NaN           NaN
#
# ...

# %%
import platform
from matplotlib import font_manager, rc

path = "c:/Windows/Fonts/malgun.ttf"
if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system.')

# %%
target_col = ['어벤져스: 인피니티 워', '레디 플레이어 원', '오션스8', '코코']
plt.figure(figsize=(12,6))
plt.plot(movie_pivot[target_col])
plt.legend(target_col, loc='best')
plt.grid()
plt.show()
